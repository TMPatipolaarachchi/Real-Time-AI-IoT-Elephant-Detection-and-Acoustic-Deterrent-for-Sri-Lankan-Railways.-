# %% [markdown]
# <a href="https://colab.research.google.com/github/TMPatipolaarachchi/Real-Time-AI-IoT-Elephant-Detection-and-Acoustic-Deterrent-for-Sri-Lankan-Railways.-/blob/ElephantDetection/TrainModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/ElephantDetection_V2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/00079_result_1_png.rf.af32b0d1e04753fcbe9fc1f1d443011e.jpg
#  extracting: train/images/00079_result_png.rf.18382df1ffc38dba8f56880ca50c6d63.jpg
#  extracting: train/images/00080_result_10_png.rf.8f114da2c3aedd407bc1b17994f8d830.jpg
#  extracting: train/images/00080_result_1_png.rf.9d1f98430ee5dfa21245a7fe35a66ed2.jpg
#  extracting: train/images/00080_result_2_png.rf.3797acd397e1fcf3d5a06db3a3c9d6fb.jpg
#  extracting: train/images/00080_result_3_png.rf.21dccec77b9b901d0c4df50b7453ca24.jpg
#  extracting: train/images/00080_result_4_png.rf.1d2988d19bce4a7e7f90f1529fb5e72f.jpg
#  extracting: train/images/00080_result_4_png_jpg.rf.03e994e5d79aa130752a33b9583d314a.jpg
#  extracting: train/images/00080_result_6_png.rf.760a84d519b341564f74c227b7c37c13.jpg
#  extracting: train/images/00080_result_7_png.rf.e3e72809ced4c70513a9fc9403fb53dc.jpg
# ...

# %%
# !ls train/images | head
# !ls valid/labels | head
# !ls valid/images | head
# !ls train/labels | head
# Out:
# 00000_20190620_1615_1616_png.rf.e91058e9457db5e714a07b76ec6beac8.jpg
# 00000_result_10-Copy_png.rf.3e995f195c8ed58a34d54d914ec480f4.jpg
# 00000_result_12-Copy_png.rf.384bf58d60aa41df4eeaf8aa4a52549f.jpg
# 00000_result_12_png_jpg.rf.c79ed27cd16d1d8047d1ab2d76e7c269.jpg
# 00000_result_13_png.rf.68d5436b9439e0082be83d7112a1874f.jpg
# 00000_result_16-Copy_png.rf.dbf28b37a869a5bbf64339f70704092a.jpg
# 00000_result_18_png.rf.aca650197f5cf6861c9a9bd7abf36670.jpg
# 00000_result_1_png.rf.a011b958ed9d565190ff49f8d3a25293.jpg
# 00000_result_23_png_jpg.rf.d74d89acd7c019716effaab878663c87.jpg
# 00000_result_29_png.rf.a93ccfdf1cc5aacf8dee086df8b36220.jpg
# 00000_20190620_1613_1614_png.rf.d3a0ed77ea66d9185c7addeafe534569.txt
# 00000_result_17-Copy_png.rf.711f6ccf5ad16cbe36cc1949d9d94fec.txt
# 00000_result_4_png_jpg.rf.dd3ab65ded3e90d96bbb869d5050c5dc.txt
# 00000_result_6-Copy_png.rf.e7ada249fd4970575f9f7fa9cab7e79a.txt
# 00002_result_10_png.rf.4b4b9b00992628e3278dcf203a4cc020.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.247 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
